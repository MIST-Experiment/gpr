# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
out0 = np.fromfile(open("/home/gprlab/Desktop/gpr/gnu_log/out0_log"), dtype="complex64")# Create a subplot for each file
out1 = np.fromfile(open("/home/gprlab/Desktop/gpr/gnu_log/out1_log"), dtype="complex64")# Create a subplot for each file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 out0 = np.fromfile(open("/home/gprlab/Desktop/gpr/gnu_log/out0_log"), dtype="complex64")# Create a subplot for each file
#       2 out1 = np.fromfile(open("/home/gprlab/Desktop/gpr/gnu_log/out1_log"), dtype="complex64")# Create a subplot for each file
#
# File ~/miniconda3/envs/env0/lib/python3.11/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# ...

# %%
clock = np.arange(len(out0[24000000:36000000]))

# %%
plt.plot(clock, out0[24000000:36000000])
# Out:
# /home/gprlab/miniconda3/envs/gprdev/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
corr = scipy.signal.correlate(out0[24000000:36000000], out1[27000000:39000000])

# %%
plt.plot(np.arange(len(corr)), corr)

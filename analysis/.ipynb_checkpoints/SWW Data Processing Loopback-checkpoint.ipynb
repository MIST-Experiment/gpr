# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import matplotlib
import scipy.signal.windows as windows
import re
import os

from scipy.fft import fft, fftshift, ifft, ifftshift, fftfreq

matplotlib.style.use('bmh')

# %%
"""rx_buffer1_files = [
    "ch1_400_1000_50cm_antennatest5-4.npy",
    "ch1_400_1000_60cm_antennatest5-3.npy",
    "ch1_400_1000_70cm_antennatest5-2.npy",
    "ch1_400_1000_80cm_antennatest5-1.npy",
    "ch1_400_1000_90cm_antennatest5-9.npy",
    "ch1_400_1000_100cm_antennatest5-8.npy",
    "ch1_400_1000_112cm_antennatest5-7.npy",
    "ch1_400_1000_136cm_antennatest5-6.npy",
    "ch1_400_1000_157cm_antennatest5-5.npy"
    
    
    
    
]

rx_buffer2_files = [
    "ch2_400_1000_50cm_antennatest5-4.npy",
    "ch2_400_1000_60cm_antennatest5-3.npy",
    "ch2_400_1000_70cm_antennatest5-2.npy",
    "ch2_400_1000_80cm_antennatest5-1.npy",
    "ch2_400_1000_90cm_antennatest5-9.npy",
    "ch2_400_1000_100cm_antennatest5-8.npy",
    "ch2_400_1000_112cm_antennatest5-7.npy",
    "ch2_400_1000_136cm_antennatest5-6.npy",
    "ch2_400_1000_157cm_antennatest5-5.npy"
    
]"""
"""
rx_buffer1_files = [
    "ch1_400_1000_157cm_antennatest6-1.npy",
    "ch1_400_1000_136cm_antennatest6-2.npy",
    "ch1_400_1000_112cm_antennatest6-3.npy",
    "ch1_400_1000_100cm_antennatest6-4.npy",
    "ch1_400_1000_90cm_antennatest6-5.npy",
    "ch1_400_1000_80cm_antennatest6-6.npy",
    "ch1_400_1000_70cm_antennatest6-7.npy",
    "ch1_400_1000_60cm_antennatest6-8.npy",
    "ch1_400_1000_50cm_antennatest6-9.npy",
    "ch1_400_1000_50cm_antennatest5-4.npy",
    "ch1_400_1000_60cm_antennatest5-3.npy",
    "ch1_400_1000_70cm_antennatest5-2.npy",
    "ch1_400_1000_80cm_antennatest5-1.npy",
    "ch1_400_1000_90cm_antennatest5-9.npy",
    "ch1_400_1000_100cm_antennatest5-8.npy",
    "ch1_400_1000_112cm_antennatest5-7.npy",
    "ch1_400_1000_136cm_antennatest5-6.npy",
    "ch1_400_1000_157cm_antennatest5-5.npy",
    "ch1_400_1000_100cm_antennatest2-2.npy",
    "ch1_400_1000_140cm_antennatest2-4.npy",
    "ch1_400_1000_190cm_antennatest2-6.npy",
    "ch1_400_1000_280cm_antennatest2-8.npy",
    "ch1_400_1000_360cm_antennatest2-10.npy",
    "ch1_400_1000_111cm_antennatest2-3.npy",
    "ch1_400_1000_191cm_antennatest2-7.npy",
    "ch1_400_1000_281cm_antennatest2-9.npy",
    "ch1_400_1000_141cm_antennatest2-5.npy",
    "ch1_400_1000_361cm_antennatest2-11.npy",
    "ch1_400_1000_48cm_antennatest0.npy",
    "ch1_400_1000_30cm_antennatest0.npy",
    "ch1_400_1000_0cm_antennatest0.npy",
    "ch1_400_1000_265cm_antennatest0.npy",
    "ch1_400_1000_295cm_antennatest0.npy",
    "ch1_400_1000_75cm_antennatest7-3.npy",
    "ch1_400_1000_50cm_antennatest7-2.npy",
    "ch1_400_1000_29cm_antennatest7-1.npy"
    
    
    
]



rx_buffer2_files = [
    "ch2_400_1000_157cm_antennatest6-1.npy",
    "ch2_400_1000_136cm_antennatest6-2.npy",
    "ch2_400_1000_112cm_antennatest6-3.npy",
    "ch2_400_1000_100cm_antennatest6-4.npy",
    "ch2_400_1000_90cm_antennatest6-5.npy",
    "ch2_400_1000_80cm_antennatest6-6.npy",
    "ch2_400_1000_70cm_antennatest6-7.npy",
    "ch2_400_1000_60cm_antennatest6-8.npy",
    "ch2_400_1000_50cm_antennatest6-9.npy",
    "ch2_400_1000_50cm_antennatest5-4.npy",
    "ch2_400_1000_60cm_antennatest5-3.npy",
    "ch2_400_1000_70cm_antennatest5-2.npy",
    "ch2_400_1000_80cm_antennatest5-1.npy",
    "ch2_400_1000_90cm_antennatest5-9.npy",
    "ch2_400_1000_100cm_antennatest5-8.npy",
    "ch2_400_1000_112cm_antennatest5-7.npy",
    "ch2_400_1000_136cm_antennatest5-6.npy",
    "ch2_400_1000_157cm_antennatest5-5.npy",
    "ch2_400_1000_100cm_antennatest2-2.npy",
    "ch2_400_1000_140cm_antennatest2-4.npy",
    "ch2_400_1000_190cm_antennatest2-6.npy",
    "ch2_400_1000_280cm_antennatest2-8.npy",
    "ch2_400_1000_360cm_antennatest2-10.npy",
    "ch2_400_1000_111cm_antennatest2-3.npy",
    "ch2_400_1000_191cm_antennatest2-7.npy",
    "ch2_400_1000_281cm_antennatest2-9.npy",
    "ch2_400_1000_141cm_antennatest2-5.npy",
    "ch2_400_1000_361cm_antennatest2-11.npy",
    "ch2_400_1000_48cm_antennatest0.npy",
    "ch2_400_1000_30cm_antennatest0.npy",
    "ch2_400_1000_0cm_antennatest0.npy",
    "ch2_400_1000_265cm_antennatest0.npy",
    "ch2_400_1000_295cm_antennatest0.npy",
    "ch2_400_1000_75cm_antennatest7-3.npy",
    "ch2_400_1000_50cm_antennatest7-2.npy",
    "ch2_400_1000_29cm_antennatest7-1.npy"
]

"""
"""
rx_buffer1_files = [
    "ch1_400_1000_0cm_antennatest0.npy",
    "ch1_400_1000_265cm_antennatest0.npy",
    "ch1_400_1000_295cm_antennatest0.npy",
    "ch1_400_1000_190cm_antennatest2-6.npy",
    "ch1_400_1000_50cm_antennatest6-9.npy",
    "ch1_400_1000_111cm_antennatest2-3.npy",
    "ch1_400_1000_157cm_antennatest5-5.npy",
    "ch1_400_1000_190cm_antennatest2-6.npy",
    "ch1_400_1000_280cm_antennatest2-8.npy",
    "ch1_400_1000_360cm_antennatest2-10.npy"
    
    
]

rx_buffer2_files = [
     "ch2_400_1000_0cm_antennatest0.npy",
     "ch2_400_1000_265cm_antennatest0.npy",
     "ch2_400_1000_295cm_antennatest0.npy",
     "ch1_400_1000_190cm_antennatest2-6.npy",
     "ch2_400_1000_50cm_antennatest6-9.npy",
     "ch2_400_1000_111cm_antennatest2-3.npy",
     "ch2_400_1000_157cm_antennatest5-5.npy",
     "ch2_400_1000_190cm_antennatest2-6.npy",
     "ch2_400_1000_280cm_antennatest2-8.npy",
     "ch2_400_1000_360cm_antennatest2-10.npy"
     

    
]
"""

dir = "/home/mhetu/Desktop/gpr/data/antenna_tests8/"

rx_buffer1_files = [
    "ch1_400_1000_antennatest8-1.npy",
    "ch1_400_1000_antennatest8-2.npy",
    "ch1_400_1000_antennatest8-5.npy",
    "ch1_400_1000_antennatest8-10.npy",
    "ch1_400_1000_antennatest8-12.npy",
    "ch1_400_1000_antennatest8-13.npy",
    "ch1_400_1000_antennatest8-18.npy",
    "ch1_400_1000_antennatest8-22.npy",
]

rx_buffer2_files = [
    "ch2_400_1000_antennatest8-1.npy",
    "ch2_400_1000_antennatest8-2.npy",
    "ch2_400_1000_antennatest8-5.npy",
    "ch2_400_1000_antennatest8-10.npy",
    "ch2_400_1000_antennatest8-12.npy",
    "ch2_400_1000_antennatest8-13.npy",
    "ch2_400_1000_antennatest8-18.npy",
    "ch2_400_1000_antennatest8-22.npy"      
]

# %%
import numpy as np

# Initialize lists to store parsed data
testIDs = []
distances = []
plate = []
angle = []

# Open the file and read line by line
with open(dir+"antennaTest8", 'r') as file:
    # Skip the first line (header)
    next(file)
    next(file)
    
    # Iterate over the remaining lines
    for line in file:
        # Split the line by comma
        parts = line.strip().split(', ')
        
        # Append to lists
        testIDs.append(parts[0])
        distances.append(float(parts[9].replace('cm', '')))
        plate.append(parts[11].strip() == 'True')
        angle.append(parts[13].strip() == 'none')

# Convert lists to numpy arrays
testIDs = np.array(testIDs)
distances = np.array(distances)
plate = np.array(plate)
angle = np.array(angle)

unique_dists = np.unique(distances)

dict = {}

for dist in unique_dists:
    idxs = np.where((distances == dist) & (plate == False) & (angle == True))
    print(dist)
    print(testIDs[idxs])
    dict[dist] = testIDs[idxs]
# Out:
# 112.0
# []
# 186.0
# []
# 211.0
# ['8-26']
# 231.0
# ['8-1' '8-3' '8-4']
# 233.0
# []
# 294.0
# ['8-5' '8-6' '8-7']
# 338.0
# []
# 343.0
# ['8-10' '8-11']
# 395.0
# ['8-13' '8-14' '8-15' '8-16']
# 448.0
# ['8-18' '8-19' '8-20']
# 493.0
# []
# 503.0
# ['8-22' '8-23' '8-24']

# %%
delR = 3e8/(2*600e6)
maxR = 3e8/(2*10e6)

x_arr = np.linspace(0, maxR, num=int(maxR/delR))*100

for dist in unique_dists:
    for ID in dict[dist]:
        rx_buffer1 = np.load(dir+"ch2_400_1000_antennatest"+ID+".npy")
        rx_buffer2 = np.load(dir+"ch1_400_1000_antennatest"+ID+".npy")
        cms = dist
        
        fs = 20e6 #Sample frequency
        LOs = np.unique(rx_buffer1[:,1]) #The LO values encoded in the output
        nsp = len(LOs) #The number of LO values taken
        Np = min(rx_buffer1[rx_buffer1[:, 1] == LOs[i], 0].shape[0] for i in range(nsp)) #Length of a pulse
        N = len(rx_buffer1) #Length of the full buffer
        N2 = int(N/2) 
    
        W = windows.tukey(Np)
        Tp = 40001/fs #period for upsampling
        L = (fs)*Tp #Upsampling factor
        Lup = 2*L
        n_zeros = int(Lup/2)
        
        stacklen = N #Taken from the thesis
    
        #allocate an upsampled stack
        dft_stack = np.zeros(stacklen, dtype = np.complex128)
        
        for i in range(nsp):
        
            # Initializing reference waveform
            ref_chirp = rx_buffer1[rx_buffer1[:,1]==LOs[i], 0][0:N]
            rx_chirp = rx_buffer2[rx_buffer2[:,1]==LOs[i], 0][0:N]
            #plt.plot(fft(ref_chirp))
            #fx = fft(ref_chirp)
            #fx[Np//2: Np] = 0
            #fx[0:Np//2] = fx[0:Np//2]/2
            #plt.plot(fx)
            #plt.plot(fft(np.real(ref_chirp)))
            #plt.show()
            #Take FFTs and use window
            ref_dft = fft(ref_chirp)
            rx_dft = fft(rx_chirp)
 
            #Compute matched filter
            
            mf_dft = ref_dft * np.conjugate(rx_dft)
            mf_dft = mf_dft*W
    
            
            #Upsample
            zeros_start = np.zeros(n_zeros) #Upsample by shifting
            zeros_end = np.zeros(stacklen-n_zeros-Np)
            dft_shifted_padded = np.concatenate([zeros_start, mf_dft, zeros_end])
    
            
            mf_dft_shift = np.roll(dft_shifted_padded, int(i * Np)) #Shift forward to fill the space
            mf_dft_shift = fftshift(mf_dft_shift)
            freqs = fftshift(fftfreq(stacklen, 1/fs))
            
            dft_stack += mf_dft_shift
  
        mag_stack = (np.abs(dft_stack/np.max(dft_stack))**2)

        sww = ifftshift(ifft(dft_stack)) #Ifft
        
        p = 20*np.log10(np.abs(sww))

        y_arr = np.abs(sww)[int(len(sww)/2+28):int(len(sww)/2+28+int(maxR/delR))]
        y_arr /= y_arr.max()

        fig, ax = plt.subplots(figsize = (6,5))
        
        ax.plot(x_arr, y_arr)
        ax.plot([cms, cms],[0,1], linestyle = '--', alpha=0.75)
        
        ax.set_title(f"Test {ID}, {cms} cm")
        ax.set_ylabel("Amplitude")
        ax.set_xlabel("Distance (cm)")
        #sample_range = (2.645725e6, 2.645825e6)
        #sample_range = (len(sww)/2+28, len(sww)/2 + 100)
        ax.set_xlim(0, 1500)
        fig.savefig(f'Test_{ID}_{dist}cm.png', dpi=300)
        plt.show()

# %%
for file1, file2 in zip(rx_buffer1_files, rx_buffer2_files):
    rx_buffer1 = np.load(dir+file2)
    rx_buffer2 = np.load(dir+file1)
    #cms = re.search(r'(\d+)cm', file1).group(1)
    testrun = re.search(r'antennatest(\d+-\d+)', file1).group(1)    
    
    fs = 20e6 #Sample frequency
    LOs = np.unique(rx_buffer1[:,1]) #The LO values encoded in the output
    nsp = len(LOs) #The number of LO values taken
    Np = min(rx_buffer1[rx_buffer1[:, 1] == LOs[i], 0].shape[0] for i in range(nsp)) #Length of a pulse
    N = len(rx_buffer1) #Length of the full buffer
    N2 = int(N/2) 

    W = windows.tukey(Np)
    Tp = 40001/fs #period for upsampling
    L = (fs)*Tp #Upsampling factor
    Lup = 2*L
    print(Lup)
    n_zeros = int(Lup/2)
    
    stacklen = N #Taken from the thesis

    #allocate an upsampled stack
    dft_stack = np.zeros(stacklen, dtype = np.complex128)
    
    for i in range(nsp):
    
        # Initializing reference waveform
        ref_chirp = rx_buffer1[rx_buffer1[:,1]==LOs[i], 0][0:N]
        rx_chirp = rx_buffer2[rx_buffer2[:,1]==LOs[i], 0][0:N]
        #plt.plot(fft(ref_chirp))
        #fx = fft(ref_chirp)
        #fx[Np//2: Np] = 0
        #fx[0:Np//2] = fx[0:Np//2]/2
        #plt.plot(fx)
        #plt.plot(fft(np.real(ref_chirp)))
        #plt.show()
        #Take FFTs and use window
        ref_dft = fft(ref_chirp)
        rx_dft = fft(rx_chirp)
    
    
        
        #Compute matched filter
        
        mf_dft = ref_dft * np.conjugate(rx_dft)
        mf_dft = mf_dft*W

        
        #Upsample
        zeros_start = np.zeros(n_zeros) #Upsample by shifting
        zeros_end = np.zeros(stacklen-n_zeros-Np)
        dft_shifted_padded = np.concatenate([zeros_start, mf_dft, zeros_end])

        
        mf_dft_shift = np.roll(dft_shifted_padded, int(i * Np)) #Shift forward to fill the space
        mf_dft_shift = fftshift(mf_dft_shift)
        freqs = fftshift(fftfreq(stacklen, 1/fs))
        
        dft_stack += mf_dft_shift
    #print(dft_stack)


    mag_stack = 20*np.log10(np.abs(dft_stack/np.max(dft_stack))**2)
    
    
    
    sww = ifftshift(ifft(dft_stack)) #Ifft
    
    
   
    
    p = 20*np.log10(np.abs(sww))

    

    
    fig, ax = plt.subplots()
    ax.plot(np.abs(sww))
    #print(f'{cms}cm Test {testrun}')
    print(np.max(np.abs(sww)))
    print(np.argmax(np.abs(sww)))
    #2645730

    ax.set_title(f"Test {testrun}")
    ax.set_ylabel("abs(sww)")
    ax.set_xlabel("Samples")
    #sample_range = (2.645725e6, 2.645825e6)
    sample_range = (len(sww)/2, len(sww)/2 + 200)


    ax.set_xlim(sample_range)
    #fig.savefig(f'Output{cms}cm Test {testrun}.png')
    plt.show()

# %%
import numpy as np
import scipy 
import matplotlib.pyplot as plt
import getpass

# %%
filenames = ["/home/"+getpass.getuser()+"/Desktop/gnu_log/out0_log06", 
       "/home/"+getpass.getuser()+"/Desktop/gnu_log/out1_log06"]

# %%
ref = np.fromfile(open(filenames[0]), dtype="complex64")[1000000:1010000]
sig = np.fromfile(open(filenames[1]), dtype="complex64")[1000000:1010000]

# %%
plt.specgram(ref, NFFT=1024, Fs=12000000)
plt.show()

# %%
plt.specgram(sig, NFFT=1024, Fs=12000000)
plt.show()

# %%
import struct
import matplotlib.pyplot as plt
with open("/home/gprlab/Desktop/gpr/gnu_log/matched_filter_log", "rb") as file:
	data = file.read(8000000)


num_floats = len(data) // 4
floats = struct.unpack(f'<{num_floats}f', data)

plt.figure()
plt.plot(floats[1255000:1260000])

plt.show()
